# %%
# %reload_ext autoreload
# %autoreload 2

import math
import sys
from pathlib import Path

import numpy as np
import pandas as pd
from azureml.core import Workspace
from azureml.core.dataset import Dataset
from glob2 import glob
import matplotlib.pyplot as plt

sys.path.append(str(Path(os.getcwd()).parent))
from data_utilities import convert_age_from_days_to_years, draw_age_distribution, draw_sex_distribution, calculate_code_age_distribution

# %%
DATASET_PATH = Path('/mnt/omdena_dataset/realtime_evaluation')

# %%
# Takes more than 53min therefore commented out
# rgb_files = glob(str(DATASET_PATH / 'RGB/**/*.jpg'))
# len(rgb_files)

# %%
artifacts = pd.read_csv(DATASET_PATH / 'labels/realworld__depthmap_data.csv')
print("Total no. of artifacts:", len(artifacts))
artifacts.head()
# Out:
# Total no. of artifacts: 100588
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                   id  \
# 0  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 1  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 2  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 3  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 4  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
#
#                                         storage_path  height  weight  muac  \
# 0  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 1  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 2  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 3  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 4  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
#
#   scan_group  key   tag   age   sex                 qrcode
# 0        NaN  100  good  1310  male  1583462505-43bak4gvfa
# 1        NaN  100  good  1310  male  1583462505-43bak4gvfa
# 2        NaN  100  good  1310  male  1583462505-43bak4gvfa
# 3        NaN  100  good  1310  male  1583462505-43bak4gvfa
# 4        NaN  100  good  1310  male  1583462505-43bak4gvfa

# %%
artifacts.describe()
# Out:
#               height         weight           muac            key  \
# count  100588.000000  100588.000000  100588.000000  100588.000000
# mean       88.590138      11.503907      14.102531     107.695133
# std        10.345305       2.374155       1.056257      24.995791
# min        10.500000       4.400000      10.000000     100.000000
# 25%        81.800000       9.800000      13.400000     101.000000
# 50%        89.600000      11.600000      14.100000     101.000000
# 75%        95.900000      13.200000      14.800000     102.000000
# max       192.200000      19.950000      17.700000     202.000000
#
#                  age
# count  100588.000000
# mean     1203.135613
# std       432.491910
# min         0.000000
# 25%       882.000000
# 50%      1240.000000
# 75%      1552.000000
# max      2121.000000

# %%
#adding the Years column into dataframe
artifacts['Years'] = artifacts.apply(convert_age_from_days_to_years, axis=1)
artifacts.head()
# Out:
#                                                   id  \
# 0  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 1  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 2  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 3  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
# 4  6V7ZlPtGlwXry9jF_artifact-scan-pcd_15666912000...
#
#                                         storage_path  height  weight  muac  \
# 0  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 1  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 2  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 3  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
# 4  qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2  14.4
#
#   scan_group  key   tag   age   sex                 qrcode  Years
# 0        NaN  100  good  1310  male  1583462505-43bak4gvfa      4
# 1        NaN  100  good  1310  male  1583462505-43bak4gvfa      4
# 2        NaN  100  good  1310  male  1583462505-43bak4gvfa      4
# 3        NaN  100  good  1310  male  1583462505-43bak4gvfa      4
# 4        NaN  100  good  1310  male  1583462505-43bak4gvfa      4

# %%
scans = artifacts.drop_duplicates(subset='qrcode',keep ='first')
print("Total no. of children:", len(scans))
# Out:
# Total no. of children: 3000

# %%
plt.figure()
draw_sex_distribution(scans)
plt.show()
# Out:
# female    1540
# male      1460
# Name: sex, dtype: int64

# %%
plt.figure()
draw_age_distribution(scans)
plt.show()
# Out:
# 0     17
# 1    308
# 2    549
# 3    756
# 4    796
# 5    569
# 6      5
# Name: Years, dtype: int64

# %%
## keys for different scan type and their distribution in dataset
"- 100 - standing front scan",
"- 101 - standing 360 scan",
"- 102 - standing back scan",
"- 200 - lying front scan",
"- 201 - lying side scan",
"- 202 - lying back scan"
print(artifacts['key'].value_counts())
_ = artifacts['key'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.savefig('realworld_distribution.png')
# Out:
# 101    47172
# 102    23533
# 100    23152
# 201     2672
# 200     2045
# 202     2014
# Name: key, dtype: int64

# %%
artifacts['key'].plot(kind='pie', y = 'key', autopct='%1.1f%%', 
 startangle=90, shadow=False, labels=artifacts['key'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-2109813be27f> in <module>
#       1 artifacts['key'].plot(kind='pie', y = 'key', autopct='%1.1f%%',
# ----> 2  startangle=90, shadow=False, labels=artifacts['key'])
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     279         self._compute_plot_data()
#     280         self._setup_subplots()
# --> 281         self._make_plot()
#     282         self._add_table()
#     283         self._make_legend()
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1485             else:
#    1486                 blabels = None
# -> 1487             results = ax.pie(y, labels=blabels, **kwds)
#    1488
#    1489             if kwds.get("autopct", None) is not None:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels)
#    3017                              verticalalignment='center')
#    3018                 props.update(textprops)
# -> 3019                 t = self.text(xt, yt, s, **props)
#    3020
#    3021                 autotexts.append(t)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/axes/_axes.py in text(self, x, y, s, fontdict, withdash, **kwargs)
#     769         t.update(effective_kwargs)
#     770
# --> 771         t.set_clip_path(self.patch)
#     772         self._add_text(t)
#     773         return t
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/text.py in set_clip_path(self, path, transform)
#     540     def set_clip_path(self, path, transform=None):
#     541         # docstring inherited.
# --> 542         super().set_clip_path(path, transform)
#     543         self._update_clip_properties()
#     544
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/artist.py in set_clip_path(self, path, transform)
#     759         if transform is None:
#     760             if isinstance(path, Rectangle):
# --> 761                 self.clipbox = TransformedBbox(Bbox.unit(),
#     762                                                path.get_transform())
#     763                 self._clippath = None
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/transforms.py in unit()
#     764     def unit():
#     765         """Create a new unit `Bbox` from (0, 0) to (1, 1)."""
# --> 766         return Bbox(np.array([[0.0, 0.0], [1.0, 1.0]], float))
#     767
#     768     @staticmethod
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f1f96fce2f0> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/numpy/lib/function_base.py in iterable(y)
#     282     try:
# --> 283         iter(y)
#     284     except TypeError:
#
# TypeError: 'float' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2077                             print_method, dpi=dpi, orientation=orientation),
#    2078                         draw_disabled=True)
# -> 2079                     self.figure.draw(renderer)
#    2080                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#    2081                     bbox_inches = self.figure.get_tightbbox(renderer,
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1734             self.patch.draw(renderer)
#    1735             mimage._draw_list_compositing_images(
# -> 1736                 renderer, self, artists, self.suppressComposite)
#    1737
#    1738             renderer.close_group('figure')
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#     683
#     684         with _wrap_text(self) as textobj:
# --> 685             bbox, info, descent = textobj._get_layout(renderer)
#     686             trans = textobj.get_transform()
#     687
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     276         of a rotated text when necessary.
#     277         """
# --> 278         key = self.get_prop_tup(renderer=renderer)
#     279         if key in self._cached:
#     280             return self._cached[key]
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/text.py in get_prop_tup(self, renderer)
#     844         need to know if the text has changed.
#     845         """
# --> 846         x, y = self.get_unitless_position()
#     847         renderer = renderer or self._renderer
#     848         return (x, y, self.get_text(), self._color,
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/text.py in get_unitless_position(self)
#     826         # This will get the position with all unit information stripped away.
#     827         # This is here for convenience since it is done in several locations.
# --> 828         x = float(self.convert_xunits(self._x))
#     829         y = float(self.convert_yunits(self._y))
#     830         return x, y
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     176         if ax is None or ax.xaxis is None:
#     177             return x
# --> 178         return ax.xaxis.convert_units(x)
#     179
#     180     def convert_yunits(self, y):
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1562     def convert_units(self, x):
#    1563         # If x is natively supported by Matplotlib, doesn't need converting
# -> 1564         if munits._is_natively_supported(x):
#    1565             return x
#    1566
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/matplotlib/units.py in _is_natively_supported(x)
#      62     """
#      63     # Matplotlib natively supports all number types except Decimal.
# ---> 64     if np.iterable(x):
#      65         # Assume lists are homogeneous as other functions in unit system.
#      66         for thisx in x:
#
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/numpy/lib/function_base.py in iterable(y)
#     281     """
#     282     try:
# --> 283         iter(y)
#     284     except TypeError:
#     285         return False
#
# KeyboardInterrupt:

# %%
calculate_code_age_distribution(artifacts)
# Out:
#          0     1     2      3      4
# codes
# 100    109  1013  4146   6340   6810
# 101    238  1507  7843  13674  14742
# 102    101  1201  4319   6345   6699
# 200     69  1547   376     28     25
# 201     62  1995   512     44     59
# 202     44  1586   332     28     24

# %%
calculate_code_age_distribution(scans)
# Out:
#         0    1    2    3    4
# codes
# 100    11  131  504  752  792
# 200     6  177   45    4    3
# 101     0    0    0    0    1

# %%
#distribution of height against age
height_vs_age = scans.plot.scatter(x='height', y='age', c='red')

# %%
#distribution of weight against age
weight_vs_age = scans.plot.scatter(x='weight',
                      y='age',
                      c='red')

# %%
## distribution of height against weight
weight_vs_height = scans.plot.scatter(x='height', y='weight', c='red')
plt.xlim([0, 150])
plt.savefig('HvW_test.png')

# %%
good_qrc = scans[scans['tag'] == 'good']['qrcode'].unique()
bad_qrc = scans[scans['tag'] == 'bad']['qrcode'].unique()
print("Total good qrcodes:", len(good_qrc))
print("Total bad qrcodes:", len(bad_qrc))
# Out:
# Total good qrcodes: 2383
# Total bad qrcodes: 602

# %% [markdown]
# ### rgb data scans

# %%
## reading the rgb csv files
rgb_artifacts = pd.read_csv(DATASET_PATH / 'labels/realworld__rgb_data.csv')
rgb_artifacts
# Out:
# /anaconda/envs/CGM_QA_Pipeline/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                     paths  \
# 0       rgb_1583462505-43bak4gvfa_1591122173510_100_10...
# 1       rgb_1583462505-43bak4gvfa_1591122173510_100_10...
# 2       rgb_1583462505-43bak4gvfa_1591122173510_100_10...
# 3       rgb_1583462505-43bak4gvfa_1591122173510_100_10...
# 4       rgb_1583462505-43bak4gvfa_1591122173510_100_10...
# ...                                                   ...
# 353013  rgb_1598382355-k5eyhov4bu_1598382355094_102_10...
# 353014  rgb_1598382355-k5eyhov4bu_1598382355094_102_10...
# 353015  rgb_1598382355-k5eyhov4bu_1598382355094_102_10...
# 353016  rgb_1598382355-k5eyhov4bu_1598382355094_102_10...
# 353017  rgb_1598382355-k5eyhov4bu_1598382355094_102_10...
#
#                                                        id  \
# 0       6V7ZlPtGlwXry9jF_artifact-scan-rgb_15666912000...
# 1       6V7ZlPtGlwXry9jF_artifact-scan-rgb_15666912000...
# 2       6V7ZlPtGlwXry9jF_artifact-scan-rgb_15666912000...
# 3       6V7ZlPtGlwXry9jF_artifact-scan-rgb_15666912000...
# 4       6V7ZlPtGlwXry9jF_artifact-scan-rgb_15666912000...
# ...                                                   ...
# 353013  q0af6iytLCKl7SMX_artifact-scan-rgb_15839712000...
# 353014  q0af6iytLCKl7SMX_artifact-scan-rgb_15839712000...
# 353015  q0af6iytLCKl7SMX_artifact-scan-rgb_15839712000...
# 353016  q0af6iytLCKl7SMX_artifact-scan-rgb_15839712000...
# 353017  q0af6iytLCKl7SMX_artifact-scan-rgb_15839712000...
#
#                                              storage_path  height  weight  \
# 0       qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2
# 1       qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2
# 2       qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2
# 3       qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2
# 4       qrcode/1583462505-43bak4gvfa/measure/159112217...    95.5    13.2
# ...                                                   ...     ...     ...
# 353013  qrcode/1598382355-k5eyhov4bu/measure/159838235...    92.0    11.4
# 353014  qrcode/1598382355-k5eyhov4bu/measure/159838235...    92.0    11.4
# 353015  qrcode/1598382355-k5eyhov4bu/measure/159838235...    92.0    11.4
# 353016  qrcode/1598382355-k5eyhov4bu/measure/159838235...    92.0    11.4
# 353017  qrcode/1598382355-k5eyhov4bu/measure/159838235...    92.0    11.4
#
#         muac scan_group  key   tag   age     sex                 qrcode
# 0       14.4        NaN  100  good  1310    male  1583462505-43bak4gvfa
# 1       14.4        NaN  100  good  1310    male  1583462505-43bak4gvfa
# 2       14.4        NaN  100  good  1310    male  1583462505-43bak4gvfa
# 3       14.4        NaN  100  good  1310    male  1583462505-43bak4gvfa
# 4       14.4        NaN  100  good  1310    male  1583462505-43bak4gvfa
# ...      ...        ...  ...   ...   ...     ...                    ...
# 353013  14.3        NaN  102  good  1350  female  1598382355-k5eyhov4bu
# 353014  14.3        NaN  102  good  1350  female  1598382355-k5eyhov4bu
# 353015  14.3        NaN  102  good  1350  female  1598382355-k5eyhov4bu
# 353016  14.3        NaN  102  good  1350  female  1598382355-k5eyhov4bu
# 353017  14.3        NaN  102  good  1350  female  1598382355-k5eyhov4bu
#
# [353018 rows x 12 columns]

# %%
print(rgb_artifacts['key'].value_counts())
_ = rgb_artifacts['key'].value_counts().plot(kind='pie')
# Out:
# 101    169256
# 100     80747
# 102     79823
# 201      9150
# 202      7075
# 200      6967
# Name: key, dtype: int64
